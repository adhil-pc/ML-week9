# %% [markdown]
# Q:What is vector space?
# Ans:It is the collection of vectors where you can add vectors multiply vectors  by scaling them, and the result still ramain in the same space.
#
# VECTOR: vector represents the displacement/movement with both magnitude and direction
#
# SALAR: Scalar gives the magnitude only but not the direction
#
# SPAN: Span really means all direction that you can reach by scaling and adding(linear combination) the given vectors[used in PCA]
#                     OR
# Span is set of all possible LINEAR COMBINATION of given vectors
#
# BASIS VECTORS: Any vectors can be made using basis vectors eg..,(1,0)&(0,1)
#
# LINEAR COMBINATION: Linear combination is weighted sum of features or Vectors.literally it is scaling and adding the vectors[used in Linear regression,Nueral network]
#
# TRANSFORMATION: Transformation is a mapping that converts an input vector in to an another vector on the basis of some rule
#
# LINEAR TRANSFORMATION: A LT changes vector withou bending or curving the co-ordinate grid
#
# MATRIX: It is a way of recording where the basis vectors go under LT
#
# MATRIX MULTIPLICATION: Is a mathematical way to combine 2 LT in to a single LT
#
# DETERMINANT: Tells us how a LT changes area and wether transformation flip space
#
# Q:Why do ML needs LINEAR ALGEBRA?
# ans: Because DATA represented as VECTORS, TRANSFORMATIONS are stored as MATRICES, MODELS learn by solvig SYSTEM OF LINAER EQUATIONS and LINAER ALGEBRA provides language and tools for that.
# *Important applications are:
# A)FEATURE TRANSFROMATION:It  is the process of converting original feature into a new representation that is more usefull for the model to learn algorithm.
# B)DIMENSIONALLY REDUCTION: Some times data have so many features, we transfrom it into smaller number of features by keeping most of the important informations.[PCA]
#
#
# DOT PRODUCT: It gives how much two vectors points in the same direction[Used in LINEAR REGRESSION]
# CROSS PRODCT: it produce a perpendicular vector to both input vectors
#
# #note: Cofactor is a minor with sign attached
#
# EIGEN VECTORS: Usually after transformation the vector length and direction both changes , Eigen vector is a special vector even after transformation its direction does not changes but its length will vary .[ML perspective] Represent an important direction/pattern in the data that remains unchaged after transformation.
#
# EIGEN VALUES: Tells how much the EIGEN VECTOR shrunks/stretc.[ML Perspective]An eigenvalue measures the amount of variance (information) present in the direction pointed to by its corresponding eigenvector.
#
# Q:How EIGEN VALUES AND VECTORS WORKS IN PCA:
# Ans:In PCA, Eigen vector represents the principal direction along with the data varies the most, While Eigen value measure the amount of Variance (information) captured by each principal component.PCA keeps the eigen vectors with largest eigen values to reduce dimensionality while retaining the maximum information.
#
# DIAGONALISATION: Converting a matrix in to equivalent diagonal matrix using its eignevalues and eigen vectors
#
# INVERSE OF A MATRIX: An inverse undoes or reverse TRANSFORMATION.
#
# #CALCULUS
# LIMITS: A limit describe the value that function approaches as the input approaches  a particular way. In ML limits are important because derivatives are defined using limits.
#
# CONTINUITY: A function is continues if it has no breaks,jumps or hole.in ML continues loss functions are prefered because they allow smooth optimisation and make derivatives computable.
#
# DERIVATIVE:A derivative measure rate of change of function w.r.t its input.in ML derivative tells how the loss changes when model parameters are changed, helping us update prameter in the correct direction.
#
# #INTEGRATION:It is the mathematical way to find area under curve.It is the reverse operaton of differentiation.ntegration is mainly used in probability theory, probability distributions, Bayesian learning, and statistical modeling to compute probabilities and expectations.
#
# Q:How calculus Helps ML?
# Ans:Calculus helps ML models learn by optimizing a loss fucntion. DERIVATIVE provide information about how model parameter affect the loss, Using algorith like GRADIENT DESCENT to minimise error and improve prediction.
#
# PCA[PRINCIPAL COMPONENT ANALYSIS]: PCA is a dimensionality reduction technique that transfroms data into new set of direction called PRINCIPAL COMPONENTS. These components are obtained from EIGEN VECTORS of the COVARIANCE MATRIX.PCA keeps the EIGENVECTORS with largest EIGENVALUES while retaining important informations.
#
# GRADIENT DESCENT: It is an optimisation algorithm used to minimise a loss function.It uses DERIVATIVES(GRADIENTS) to determine the direction in which model parameter should be updated to reduce prediction error.
#
# Q:What is the difference between GRADIENT and GRADIENT DESCEND?
# Ans:Gradient is the derivative of cost function . It indicates the direction and rate of steepest increase in loss. GRADIENT DESCENT: It is an optimisation algorithm used to minimise a loss function.It uses DERIVATIVES(GRADIENTS) to determine the direction in which model parameter should be updated to reduce prediction error.
#
#
# Q:What is the difference between cost and loss function?
# Ans:Loss function measure the error for a single training example, whereas Cost function measures the average loss over the entire training dataset.Gradient descent minimise the  cost function by updating the model parameter.
#
#
# Q:Why all matrices cannot be inverted?
# Ans:Because some matrices lose information during transformation.If information is lost, we cannot uniquely recover the original input.So an inverse does not exist.
# In maths, if det(matrix)=0 inverse does not exist.
#
# Q:Why matrix multiplication is not commutative?
# Ans:Matrix multiplicaton represents transformaton[AB!=BA] A-->(rotate),B-->(sclae) so (rotate,scale) is different from (scale,rotate)
# #Assosiative-->A+(B+c)=(A+B)+C
# #Distributive-->A(B+C)=AB+AC
#
#
# Q:Why feature scaling is important in GRADIENT DESCEND?
# Ans:it is important in GRADIENT DESCEND because features with large value can dominate the gradients, and failed to reach minimum efficiently.
#
# Q:What is multicollinearity?
# Ans:Multicollinearity occurs when two or more features are highly co-related,so one feature can predict from the other.
#
# Q:Why does PCA fails in non-linear data?
# Ans:PCA can only perform linear transformation,and can only find linear relationship in data.
#
#
# Q:Explain about product , chain and quotient rule
# Ans:A)PRODUCT RULE:Product rule is used when 2 functions are multiplied together.
# Why do we use it: Because differentiating each function seperately and multiplying the derivatives will not work
# eg:y=x**2(x+1)
# d(uv)/dx=u*(dv/dx)+v*(du/dx)
#
# B)Chain rule is used when one function is inside other function
# eg:y=(x**2+1)**5
# y=f(g(x))
#
# C)Quotient rule is used when one function is divided by another.
# eg:y=(x**2)/(x+1)
# (d/dx)(u/v)=(v(du/dx)-u(dv/dx))/v**2
#
#
# Q:What are the limitations of gradient descend?
# Ans:1.Can get stuck in Local minima.
# 2.Learning rate selection.
# 3.Slow convergance.
# 4.Feature scaling is needed.
#
# Q:Where in ML the partial derivative used?
# Ans:A normal derivative is used when a function has only one variable.in ML, cost function depends on many parameters like weight and biases, therfore we use partial derivatives to find how cost changes w.r.t one parameter by keeping the other constant.These partial derivatives are used in GRADIENT DESCEND to update the parameter and reduce the cost function.
#
# Q:Why do we minimize loss instead of maximizing accuracy?
# Ans:Since loss is continous and diffrentiable while accuracy is not.
#
# Q:What does a zero gradient indicates?
# Ans:It means the cost function is not changing at a point w.r.t a parameter. which means we reach at a minimum/maximum or saddle point.
